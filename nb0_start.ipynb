# %%
import pandas as pd
import os

columns = ['uf', 'cidade', 'zona', 'secao', 'cargo', 'candidato', 'votos']
df = pd.read_csv('./out.txt', sep=';', names=columns)
df
# Out:
#          uf            cidade  zona  secao       cargo           candidato  \
# 0        AC            BUJARI     9      1  Presidente              Branco
# 1        AC            BUJARI     9      1  Presidente                Nulo
# 2        AC            BUJARI     9      1  Presidente          CIRO GOMES
# 3        AC            BUJARI     9      1  Presidente     FERNANDO HADDAD
# 4        AC            BUJARI     9      1  Presidente  HENRIQUE MEIRELLES
# 5        AC            BUJARI     9      1  Presidente      JAIR BOLSONARO
# 6        AC            BUJARI     9      1  Presidente        MARINA SILVA
# 7        AC            BUJARI     9      1  Presidente         ALVARO DIAS
# 8        AC            BUJARI     9      1  Presidente     GERALDO ALCKMIN
# 9        AC            BUJARI     9      1  Presidente    GUILHERME BOULOS
# 10       AC            BUJARI     9      1  Presidente        CABO DACIOLO
# ...
